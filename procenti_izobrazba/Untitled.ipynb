# %%
import os
import pandas as pd
# Out:
# ['po-obcinah_izobrazba.csv',
#  'po-obcinah_spol.csv',
#  'po-obcinah_starost.csv',
#  'po-obcinah_trajanje-brezposelnosti.csv',
#  'po-statisticnah-regijah_izobrazba.csv',
#  'po-statisticnah-regijah_spol.csv',
#  'po-statisticnah-regijah_starost.csv',
#  'po-statisticnah-regijah_trajanje-brezposelnosti.csv',
#  'po-uradih-za-delo_izobrazba.csv',
#  'po-uradih-za-delo_spol.csv',
#  'po-uradih-za-delo_starost.csv',
#  'po-uradih-za-delo_trajanje-brezposelnosti.csv',
#  'zaposleni',
#  'zaposleni_po_obcinah.csv',
#  'zaposleni_po_regijah.csv']

# %%
df = pd.read_excel('../structured_data/zaposleni/zaposleni_po_obcinah.xlsx', header=[0, 1])

# %%
df
# Out:
#               Unnamed: 0_level_0                           2005  \
#               Unnamed: 0_level_1 Educational attainment - TOTAL
# 0                            NaN                    Sex - TOTAL
# 1                       SLOVENIA                         813529
# 2                     Ajdovščina                           6639
# 3                       Beltinci                           1613
# 4                           Bled                           3719
# ..                           ...                            ...
# 209            Rečica ob Savinji                              -
# 210  Sveti Jurij v Slov. goricah                              -
# 211                   Šentrupert                              -
# 212                        Mirna                              -
# 213             Ankaran/Ancarano                              -
#
#                                                                        \
# ...

# %%
df["2022"]
# Out:
#     Educational attainment - TOTAL Educational attainment - TOTAL.1  \
# 0                      Sex - TOTAL                              Men
# 1                           935344                           516988
# 2                             8138                             5055
# 3                             1410                              824
# 4                             3072                             1562
# ..                             ...                              ...
# 209                            534                              386
# 210                            273                              158
# 211                           1064                              759
# 212                            881                              481
# 213                           1041                              392
#
#     Educational attainment - TOTAL.2 Basic or less Basic or less.1  \
# 0                              Women   Sex - TOTAL             Men
# ...
