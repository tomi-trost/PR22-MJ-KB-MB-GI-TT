# %%
import os

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'colored_map_obcine.ipynb',
#  'colored_map_regije.ipynb',
#  'slovenija_obcine.json',
#  'slovenija_regije.json',
#  'source.txt']

# %%
import json
    
with open("slovenija_regije.json", "r", encoding="utf-8") as json_file:
    data = json.load(json_file)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import random

fig, ax = plt.subplots(figsize=(16, 9))

for features in data["features"]:
    regija = features["properties"]["NAME_1"]

    coords = features["geometry"]["coordinates"]
    coordinate_pairs = coords[0][0]
    x_coords, y_coords = zip(*coordinate_pairs)

    #ax.plot(x_coords, y_coords, marker='o')

    # Create a polygon patch using the points and fill it with a color
    polygon = Polygon(coordinate_pairs, closed=True, facecolor='lightblue', alpha=random.random())
    ax.add_patch(polygon)

ax.set_xlim(13, 16.8)
ax.set_ylim(45.4, 46.95)

ax.set_xlabel('X')
ax.set_ylabel('Y')

ax.set_title('Connected Points')

plt.show()
